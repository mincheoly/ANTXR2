# %%
import scanpy as sc

# %%
path = '/data/ANTXR2/coexpression/'

# %%
adata = sc.read(path + 'elmentaite2021_trio_level3.h5ad')

# %%
adata.obs.groupby(['sourceID', 'study','level_3_annot']).size()
# Out:
# /tmp/ipykernel_65539/1628764888.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs.groupby(['sourceID', 'study','level_3_annot']).size()
# sourceID   study           level_3_annot
# 3p_sanger  Elmentaite2021  Crypt_fibroblast_PI16     7471
#                            Enterocyte               13691
#                            Macrophage                 930
# 5p_sanger  Elmentaite2021  Crypt_fibroblast_PI16    11396
#                            Enterocyte               21371
#                            Macrophage                2023
# dtype: int64

# %%
adata.obs.columns
# Out:
# Index(['sampleID', 'level_1_annot', 'level_2_annot', 'level_3_annot',
#        'n_counts', 'cell_type_ontology_term_id', 'sourceID', 'study',
#        'donorID_unified', 'donor_category', 'donor_disease', 'organ_unified',
#        'age_unified', 'sample_type', 'sample_category', 'sample_retrieval',
#        'tissue_fraction', 'cell_fraction_unified', 'cell_sorting',
#        'organ_groups', 'control_vs_disease', 'tissue_ontology_term_id',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'assay_ontology_term_id', 'sex_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'is_primary_data',
#        'suspension_type', 'tissue_type', 'donor_id', 'cell_type', 'assay',
#        'disease', 'sex', 'tissue', 'self_reported_ethnicity',
#        'development_stage', 'observation_joinid', 'capture_rate_chem',
#        'capture_rate_pbmc'],
#       dtype='object')

# %%
adata.obs.groupby(['cell_type', 'donorID_unified', 'sourceID']).size().reset_index().query('donorID_unified == "D1"')
# Out:
# /tmp/ipykernel_65539/544398726.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs.groupby(['cell_type', 'donorID_unified', 'sourceID']).size().reset_index().query('donorID_unified == "D1"')
#       cell_type donorID_unified   sourceID    0
# 0    fibroblast              D1  3p_sanger   18
# 1    fibroblast              D1  5p_sanger    0
# 76   macrophage              D1  3p_sanger   87
# 77   macrophage              D1  5p_sanger    0
# 152  enterocyte              D1  3p_sanger  786
# 153  enterocyte              D1  5p_sanger    0

# %%
adata.obs.
